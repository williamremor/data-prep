# %% [markdown]
# # Desafio (Parte 2) - Extraindo Informações

# %% [markdown]
# ## Case baseado no desafio do Kaggle: "Instacart Market Basket Analysis"
#
# Esse desafio é baseado em uma competição do Kaggle ([https://www.kaggle.com](https://www.kaggle.com)) de 2017, onde é pedido para fazer a predição de se um produto será comprado por dado usuário no carrinho atual, baseado em suas compras anteriores.
#
# Não está no escopo da aula
#
#
#
# Link para o desafio: [https://www.kaggle.com/c/instacart-market-basket-analysis](https://www.kaggle.com/c/instacart-market-basket-analysis)
#
# ## Origem dos Dados:
#
# Os dados mostrados nesse desafio são uma amostra extraída do dataset disponibilizado gratuitamente pela empresa Instacart ([https://www.instacart.com/](https://www.instacart.com/)) **\***. São dados reais do banco de dados da empresa, que foram anonimizados para o uso por pesquisadores e em competições de Data Science.
#
#
# ###### * “The Instacart Online Grocery Shopping Dataset 2017”, Accessed from [https://www.instacart.com/datasets/grocery-shopping-2017](https://www.instacart.com/datasets/grocery-shopping-2017) on March 10, 2017.
#
# ## Tabelas e Colunas Importantes
#
# As Tabelas e suas respectivas colunas estão mostradas abaixo, junto com a descrição do significado de cada coluna:
#
# * Colunas da Tabela `orders`:
#
#     * ´order_id´: order identifier
#     * ´user_id´: customer identifier
#     * ´eval_set´: which evaluation set this order belongs in (see SET described below)
#     * ´order_number´: the order sequence number for this user (1 = first, n = nth)
#     * ´order_dow´: the day of the week the order was placed on
#     * ´order_hour_of_day´: the hour of the day the order was placed on
#     * ´days_since_prior´: days since the last order, capped at 30 (with NAs for order_number = 1)
#
# * Colunas da Tabela `products (50k rows):
#
#     * ´product_id´: product identifier
#     * ´product_name´: name of the product
#     * ´aisle_id´: foreign key
#     * ´department_id´: foreign key
#
# * Colunas da Tabela `aisles (134 rows):
#
#     * ´aisle_id´: aisle identifier
#     * ´aisle´: the name of the aisle
#
# * Colunas da Tabela `deptartments (21 rows):
#
#     * ´department_id´: department identifier
#     * ´department´: the name of the department
#
# * Colunas da Tabela `order_products__SET (30m+ rows):
#
#     * ´order_id´: foreign key
#     * ´product_id´: foreign key
#     * ´add_to_cart_order´: order in which each product was added to cart
#     * ´reordered´: 1 if this product has been ordered by this user in the past, 0 otherwise

# %% [markdown]
# ___

# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # Objetivo:
#
# Analisar o dataset gerado na Seção 3 e responder às questões.

# %% [markdown]
# # Dataset

# %%
file_name = os.path.join("data", "dataset.csv")

# %%
dataset = pd.read_csv(file_name, sep=",", index_col=0, encoding="utf-8")
# Out:
# C:\Users\tati\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
""" Facilitando a vida """
# baseado em uma thread do Kaggle sobre esse desafio, os dias da semana são definidos na seguinte ordem:
week_days = ["saturday", "sunday", "monday", "tuesday", "wednesday", "thursday", "friday"]

# traduzindo no dataset
dataset.order_dow = dataset.order_dow.map(lambda wd: week_days[wd])

# %%
dataset.head()
# Out:
#    order_id  user_id  order_dow department        aisle product_name
# 0   1187899        1  wednesday  beverages  soft drinks         Soda
# 1   2757217       67   saturday  beverages  soft drinks         Soda
# 2    632715      676   saturday  beverages  soft drinks         Soda
# 3   1167274      760  wednesday  beverages  soft drinks         Soda
# 4   3347074      804    tuesday  beverages  soft drinks         Soda

# %% [markdown]
# # Questões

# %% [markdown]
# ## A) Quantos usuários únicos fizeram pedidos?

# %%
""" Entre com o Código aqui """
len(dataset.user_id.unique())
#dataset.user_id.unique().shape[0]
# Out:
# 117221

# %% [markdown]
# ## B) Qual o produto que apareceu em mais pedidos?

# %%
""" Entre com o Código aqui """
dataset.product_name.value_counts()
# Out:
# Banana                                                16784
# Bag of Organic Bananas                                13790
# Organic Strawberries                                   9740
# Organic Baby Spinach                                   8734
# Large Lemon                                            7254
# Organic Avocado                                        6642
# Organic Hass Avocado                                   6545
# Strawberries                                           5775
# Limes                                                  5383
# Organic Raspberries                                    5002
# Organic Blueberries                                    4473
# Organic Whole Milk                                     4384
# Organic Cucumber                                       4122
# Organic Zucchini                                       4108
# Organic Yellow Onion                                   3790
# Organic Garlic                                         3686
# Seedless Red Grapes                                    3594
# Asparagus                                              3462
# Organic Red Onion                                      3442
# Organic Grape Tomatoes                                 3436
# Yellow Onions                                          3363
# Organic Baby Carrots                                   3228
# Honeycrisp Apple                                       3172
# Organic Cilantro                                       3164
# Organic Lemon                                          3119
# Sparkling Water Grapefruit                             2990
# Raspberries                                            2924
# Organic Fuji Apple                                     2882
# Small Hass Avocado                                     2782
# Broccoli Crown                                         2633
#                                                       ...
# Chicken With Spinach Fettuccine                           1
# Coffea Cruda 30 C                                         1
# Reduced Sodium Sunflower Seeds                            1
# Slow Churned Light Coffee Ice Cream                       1
# Louis Jadot Chardonnay, Macon Villages                    1
# Vitamin C Rejuvenating Oil-Free Moisturizer               1
# 70% Dark Chocolate for Baking                             1
# Homestyle Meals Organic Baby Food                         1
# Migraine Pain Reliever Coated Caplets                     1
# Queso Cotija                                              1
# Kalifornia Kolsch                                         1
# Greek 100 Calories Vanilla Fat Free Yogurt                1
# Edamame Soybeans In Pods                                  1
# Dynamite Hot Chili With Beans                             1
# Peanut Butter Crunch Nutrition Bar                        1
# Probiotic Supplement Capsules                             1
# Anti-Perspirant Deodorant, Clear Gel, Cool Wave           1
# Premium Young Sweet Peas                                  1
# Dried Minced Garlic                                       1
# Tart Cherry 100% Juice                                    1
# Daily Intimate Wash Odor Block                            1
# Pinot Grigio Emerald Label                                1
# Mach3 Smooth Men's Disposable Razor                       1
# Kelp, Wild Atlantic Kombu                                 1
# Nama Shoyu Soy Sauce                                      1
# Deluxe Pistachio Mix Mixed Nuts                           1
# Chai Tea Latte The Original Cups                          1
# Cough & Bronchial Syrup, Maximum Strength, Daytime        1
# 16 Bean Soup Mix                                          1
# Stir Fry Mix                                              1
# Name: product_name, Length: 38222, dtype: int64

# %%
g = dataset.groupby(["order_id", "product_name"])
product_counts = g.count().reset_index().set_index("order_id").product_name.value_counts()
print("Produto que ocorre em mais pedidos: {} ({} ocorrências)".format(product_counts.argmax(), product_counts.max()))
# Out:
# Produto que ocorre em mais pedidos: Banana (16784 ocorrências)

# %% [markdown]
# ## C) Quais os usuários que fizeram mais e menos pedidos?

# %%
""" Entre com o Código aqui """
g = dataset.groupby(["user_id", "order_id"])
order_counts = g.count().reset_index().set_index("user_id").order_id.value_counts()
print("Usuário com mais pedidos: {} ({} ocorrências)".format(order_counts.argmax(), order_counts.max()))
print("Usuário com menos pedidos: {} ({} ocorrências)".format(order_counts.argmin(), order_counts.min()))
# Out:
# Usuário com mais pedidos: 2887678 (1 ocorrências)
# Usuário com menos pedidos: 2887678 (1 ocorrências)

# %%
dataset.head()
# Out:
#    order_id  user_id  order_dow department        aisle product_name
# 0   1187899        1  wednesday  beverages  soft drinks         Soda
# 1   2757217       67   saturday  beverages  soft drinks         Soda
# 2    632715      676   saturday  beverages  soft drinks         Soda
# 3   1167274      760  wednesday  beverages  soft drinks         Soda
# 4   3347074      804    tuesday  beverages  soft drinks         Soda

# %%
bla = dataset[["user_id", "order_id"]].drop_duplicates(["user_id", "order_id"])
values = bla.user_id.value_counts()

print("Usuário com mais pedidos: {} ({} ocorrências)".format(values.argmax(), values.max()))
print("Usuário com menos pedidos: {} ({} ocorrências)".format(values.argmin(), values.min()))
# Out:
# Usuário com mais pedidos: 8188 (1 ocorrências)
# Usuário com menos pedidos: 8188 (1 ocorrências)

# %% [markdown]
# ## D) Qual a média e o desvio padrão da quantidade de produtos presentes em um pedido um usuário?

# %%
bla = dataset[["order_id","product_name"]]
values = bla.order_id.value_counts()
values.describe()[["mean", "std"]]
# Out:
# mean    10.564191
# std      7.945047
# Name: order_id, dtype: float64

# %%
g = dataset.groupby(["order_id"])
product_counts = g.product_name.count()
product_counts.describe()[["mean", "std"]]
# Out:
# mean    10.564191
# std      7.945047
# Name: product_name, dtype: float64

# %% [markdown]
# ## E) Qual a média, a mediana, o mínimo e o máximo da quantidade de corredores (`aisles`) por departmento (`department`)?

# %%
dataset.department.unique().shape
# Out:
# (21,)

# %%
dataset.head()
# Out:
#    order_id  user_id  order_dow department        aisle product_name
# 0   1187899        1  wednesday  beverages  soft drinks         Soda
# 1   2757217       67   saturday  beverages  soft drinks         Soda
# 2    632715      676   saturday  beverages  soft drinks         Soda
# 3   1167274      760  wednesday  beverages  soft drinks         Soda
# 4   3347074      804    tuesday  beverages  soft drinks         Soda

# %%
bla = dataset[["department", "aisle"]].drop_duplicates(["department", "aisle"])
values = bla.department.value_counts()
values.describe()[["mean","50%","min","max"]]
# Out:
# mean     6.380952
# 50%      5.000000
# min      1.000000
# max     17.000000
# Name: department, dtype: float64

# %%
""" Entre com o Código aqui """
aisles_per_dept = dataset[["department", "aisle"]].drop_duplicates(["department", "aisle"])
g = aisles_per_dept.groupby("department")
aisle_count = g.aisle.count()
aisle_count.describe()[["mean", "50%", "min", "max"]]
# Out:
# mean     6.380952
# 50%      5.000000
# min      1.000000
# max     17.000000
# Name: aisle, dtype: float64

# %% [markdown]
# ## F) Qual o dia da semana em que ocorrem mais pedidos de produtos para cada departmento (`department`)?

# %%
g = dataset.groupby(["department", "order_dow"])
product_count_per_dow = g.product_name.count()
product_count_per_dow_table = product_count_per_dow.unstack()
product_count_per_dow_table.head()
# Out:
# order_dow   friday  monday  saturday  sunday  thursday  tuesday  wednesday
# department
# alcohol        683     578       640     571       929      753        853
# babies        1769    1637      3143    1929      1761     1568       1517
# bakery        6441    5081     10088    6338      5636     4799       4876
# beverages    14623   12575     20249   15324     14215    12441      12578
# breakfast     3694    3218      5936    4146      3434     3044       2984

# %%
product_count_per_dow_table.apply(lambda x: x.argmax(), axis=1)
# Out:
# department
# alcohol            thursday
# babies             saturday
# bakery             saturday
# beverages          saturday
# breakfast          saturday
# bulk               saturday
# canned goods       saturday
# dairy eggs         saturday
# deli               saturday
# dry goods pasta    saturday
# frozen             saturday
# household          saturday
# international      saturday
# meat seafood       saturday
# missing            saturday
# other              saturday
# pantry             saturday
# personal care      saturday
# pets               saturday
# produce            saturday
# snacks             saturday
# dtype: object

# %% [markdown]
# ##  G) Quais foram os 5% piores e os 5% melhores corredores (`aisle`) em termos de vendas?

# %%
""" Entre com o Código aqui """
aisles_sales_count = dataset.groupby("aisle").product_name.count()
l_inf, l_sup = aisles_sales_count.describe(percentiles=[.05, .95])[["5%", "95%"]]
l_inf, l_sup
# Out:
# (458.44999999999999, 28386.649999999991)

# %%
"""piores corredores"""
aisles_sales_count[aisles_sales_count < l_inf].sort_values()
# Out:
# aisle
# beauty                        247
# frozen juice                  251
# baby accessories              273
# baby bath body care           286
# kitchen supplies              410
# specialty wines champagnes    416
# ice cream toppings            450
# Name: product_name, dtype: int64

# %%
"""melhores corredores"""
aisles_sales_count[aisles_sales_count > l_sup].sort_values(ascending=False)
# Out:
# aisle
# fresh fruits                     134576
# fresh vegetables                 134559
# packaged vegetables fruits        70176
# yogurt                            49372
# packaged cheese                   37390
# water seltzer sparkling water     32647
# milk                              29192
# Name: product_name, dtype: int64

# %% [markdown]
# ##  H) Quais foram os 5 produtos mais comprados de cada departamento na terça-feira?
#
# ### Mostre em uma tabela como no exemplo:
#
# | departamento | 1o produto | 2o produto | 3o produto | 4o produto | 5o produto |
# |:------------ |:---------- |:---------- |:---------- |:---------- |:---------- |
# | depart 01    | prod A     | prod W     | prod L     | prod H     | prod D     |
# | depart 02    | prod X     | prod Q     | prod B     | prod S     | prod P     |
# | ...          | ...        | ...        | ...        | ...        | ...        |

# %%
""" Entre com o Código aqui """
tuesday_orders = dataset[dataset.order_dow == "tuesday"]
depart_prod_count = pd.crosstab(tuesday_orders.department, tuesday_orders.product_name)

# %%
depart_prod_count.head()
# Out:
# product_name  #2 Coffee Filters  #2 Cone White Coffee Filters  \
# department
# alcohol                       0                             0
# babies                        0                             0
# bakery                        0                             0
# beverages                     1                             1
# breakfast                     0                             0
#
# product_name  0 Calorie Fuji Apple Pear Water Beverage  \
# department
# alcohol                                              0
# babies                                               0
# bakery                                               0
# beverages                                            2
# breakfast                                            0
#
# product_name  0 Calorie Strawberry Dragonfruit Water Beverage  \
# department
# alcohol                                                     0
# babies                                                      0
# bakery                                                      0
# beverages                                                   1
# breakfast                                                   0
#
# product_name  0% Fat Blueberry Greek Yogurt  0% Fat Free Organic Milk  \
# department
# alcohol                                   0                         0
# babies                                    0                         0
# bakery                                    0                         0
# beverages                                 0                         0
# breakfast                                 0                         0
#
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# department
# alcohol                                         0
# babies                                          0
# bakery                                          0
# beverages                                       0
# breakfast                                       0
#
# product_name  0% Fat Strawberry Greek Yogurt  0% Fat Superfruits Greek Yogurt  \
# department
# alcohol                                    0                                0
# babies                                     0                                0
# bakery                                     0                                0
# beverages                                  0                                0
# breakfast                                  0                                0
#
# product_name  0% Fat Vanilla Greek Yogurt  \
# department
# alcohol                                 0
# babies                                  0
# bakery                                  0
# beverages                               0
# breakfast                               0
#
# product_name                  ...                   \
# department                    ...
# alcohol                       ...
# babies                        ...
# bakery                        ...
# beverages                     ...
# breakfast                     ...
#
# product_name  of Hanover 100 Calorie Pretzels Mini  \
# department
# alcohol                                          0
# babies                                           0
# bakery                                           0
# beverages                                        0
# breakfast                                        0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# department
# alcohol                                            0
# babies                                             0
# bakery                                             0
# beverages                                         27
# breakfast                                          0
#
# product_name  vitaminwater® XXX Acai Blueberry Pomegranate  \
# department
# alcohol                                                  0
# babies                                                   0
# bakery                                                   0
# beverages                                               18
# breakfast                                                0
#
# product_name  with Crispy Almonds Cereal  \
# department
# alcohol                                0
# babies                                 0
# bakery                                 0
# beverages                              0
# breakfast                             21
#
# product_name  with Dawn Action Pacs Fresh Scent Dishwasher Detergent Pacs  \
# department
# alcohol                                                       0
# babies                                                        0
# bakery                                                        0
# beverages                                                     0
# breakfast                                                     0
#
# product_name  with Olive Oil Mayonnaise  with Olive Oil Mayonnaise Dressing  \
# department
# alcohol                               0                                   0
# babies                                0                                   0
# bakery                                0                                   0
# beverages                             0                                   0
# breakfast                             0                                   0
#
# product_name  with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# department
# alcohol                                                    0
# babies                                                     0
# bakery                                                     0
# beverages                                                  0
# breakfast                                                  0
#
# product_name  with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum  \
# department
# alcohol                                                       0
# babies                                                        0
# bakery                                                        0
# beverages                                                     0
# breakfast                                                     0
#
# product_name  with a Splash of Mango Coconut Water
# department
# alcohol                                          0
# babies                                           0
# bakery                                           0
# beverages                                        1
# breakfast                                        0
#
# [5 rows x 19808 columns]

# %%
bla = depart_prod_count.T
bla.head()
# Out:
# department                                       alcohol  babies  bakery  \
# product_name
# #2 Coffee Filters                                      0       0       0
# #2 Cone White Coffee Filters                           0       0       0
# 0 Calorie Fuji Apple Pear Water Beverage               0       0       0
# 0 Calorie Strawberry Dragonfruit Water Beverage        0       0       0
# 0% Fat Blueberry Greek Yogurt                          0       0       0
#
# department                                       beverages  breakfast  bulk  \
# product_name
# #2 Coffee Filters                                        1          0     0
# #2 Cone White Coffee Filters                             1          0     0
# 0 Calorie Fuji Apple Pear Water Beverage                 2          0     0
# 0 Calorie Strawberry Dragonfruit Water Beverage          1          0     0
# 0% Fat Blueberry Greek Yogurt                            0          0     0
#
# department                                       canned goods  dairy eggs  \
# product_name
# #2 Coffee Filters                                           0           0
# #2 Cone White Coffee Filters                                0           0
# 0 Calorie Fuji Apple Pear Water Beverage                    0           0
# 0 Calorie Strawberry Dragonfruit Water Beverage             0           0
# 0% Fat Blueberry Greek Yogurt                               0           2
#
# department                                       deli  dry goods pasta  \
# product_name
# #2 Coffee Filters                                   0                0
# #2 Cone White Coffee Filters                        0                0
# 0 Calorie Fuji Apple Pear Water Beverage            0                0
# 0 Calorie Strawberry Dragonfruit Water Beverage     0                0
# 0% Fat Blueberry Greek Yogurt                       0                0
#
# department                                        ...    household  \
# product_name                                      ...
# #2 Coffee Filters                                 ...            0
# #2 Cone White Coffee Filters                      ...            0
# 0 Calorie Fuji Apple Pear Water Beverage          ...            0
# 0 Calorie Strawberry Dragonfruit Water Beverage   ...            0
# 0% Fat Blueberry Greek Yogurt                     ...            0
#
# department                                       international  meat seafood  \
# product_name
# #2 Coffee Filters                                            0             0
# #2 Cone White Coffee Filters                                 0             0
# 0 Calorie Fuji Apple Pear Water Beverage                     0             0
# 0 Calorie Strawberry Dragonfruit Water Beverage              0             0
# 0% Fat Blueberry Greek Yogurt                                0             0
#
# department                                       missing  other  pantry  \
# product_name
# #2 Coffee Filters                                      0      0       0
# #2 Cone White Coffee Filters                           0      0       0
# 0 Calorie Fuji Apple Pear Water Beverage               0      0       0
# 0 Calorie Strawberry Dragonfruit Water Beverage        0      0       0
# 0% Fat Blueberry Greek Yogurt                          0      0       0
#
# department                                       personal care  pets  produce  \
# product_name
# #2 Coffee Filters                                            0     0        0
# #2 Cone White Coffee Filters                                 0     0        0
# 0 Calorie Fuji Apple Pear Water Beverage                     0     0        0
# 0 Calorie Strawberry Dragonfruit Water Beverage              0     0        0
# 0% Fat Blueberry Greek Yogurt                                0     0        0
#
# department                                       snacks
# product_name
# #2 Coffee Filters                                     0
# #2 Cone White Coffee Filters                          0
# 0 Calorie Fuji Apple Pear Water Beverage              0
# 0 Calorie Strawberry Dragonfruit Water Beverage       0
# 0% Fat Blueberry Greek Yogurt                         0
#
# [5 rows x 21 columns]

# %%
top_5_prods_per_dept = bla.apply(lambda x: x.sort_values(ascending=False)[:5].index.tolist(), axis=0)
top_5_prods_per_dept.head()
# Out:
# department
# alcohol      [Cabernet Sauvignon, Sauvignon Blanc, India Pa...
# babies       [Baby Food Stage 2 Blueberry Pear & Purple Car...
# bakery       [100% Whole Wheat Bread, Organic Bread with 21...
# beverages    [Sparkling Water Grapefruit, Spring Water, Sod...
# breakfast    [Honey Nut Cheerios, Organic Old Fashioned Rol...
# dtype: object

# %%
top_5_prods_per_dept = depart_prod_count.apply(lambda x: x.sort_values(ascending=False)[:5].index.tolist(), axis=1)
top_5_prods_per_dept.head()
# Out:
# department
# alcohol      [Cabernet Sauvignon, Sauvignon Blanc, India Pa...
# babies       [Baby Food Stage 2 Blueberry Pear & Purple Car...
# bakery       [100% Whole Wheat Bread, Organic Bread with 21...
# beverages    [Sparkling Water Grapefruit, Spring Water, Sod...
# breakfast    [Honey Nut Cheerios, Organic Old Fashioned Rol...
# dtype: object

# %%
for dept in top_5_prods_per_dept.index:
    print("Department '{}':".format(dept))
    print(" - " + "\n - ".join(top_5_prods_per_dept.loc[dept]))
# Out:
# Department 'alcohol':
#  - Cabernet Sauvignon
#  - Sauvignon Blanc
#  - India Pale Ale
#  - Beer
#  - Chardonnay
# Department 'babies':
#  - Baby Food Stage 2 Blueberry Pear & Purple Carrot
#  - Gluten Free SpongeBob Spinach Littles
#  - Spinach Peas & Pear Stage 2 Baby Food
#  - Peach,  Apricot & Banana Stage 2 Baby Food
#  - Broccoli & Apple Stage 2 Baby Food
# Department 'bakery':
#  - 100% Whole Wheat Bread
#  - Organic Bread with 21 Whole Grains
#  - Ezekiel 4:9 Bread Organic Sprouted Whole Grain
#  - Organic 21 Grain Thin Sliced Bread
#  - Original Nooks & Crannies English Muffins
# Department 'beverages':
#  - Sparkling Water Grapefruit
#  - Spring Water
#  - Soda
#  - Sparkling Natural Mineral Water
#  - Lime Sparkling Water
# Department 'breakfast':
#  - Honey Nut Cheerios
#  - Organic Old Fashioned Rolled Oats
#  - Raisin Bran Cereal
#  - Cereal
#  - Cherrios Honey Nut
# Department 'bulk':
#  - Dried Mango
#  - Organic Rolled Oats
#  - Organic Black Mission Figs
#  - Apricots
#  - Vegetable Chips
# Department 'canned goods':
#  - Organic Black Beans
#  - No Salt Added Black Beans
#  - Organic Garbanzo Beans
#  - Organic Diced Tomatoes
#  - Organic AppleApple
# Department 'dairy eggs':
#  - Organic Whole Milk
#  - Half & Half
#  - Organic Half & Half
#  - Unsweetened Almondmilk
#  - Organic Unsweetened Almond Milk
# Department 'deli':
#  - Original Hummus
#  - Uncured Genoa Salami
#  - Organic Extra Firm Tofu
#  - Oven Roasted Turkey Breast
#  - Organic Roasted Turkey Breast
# Department 'dry goods pasta':
#  - Marinara Sauce
#  - Organic Tomato Basil Pasta Sauce
#  - Basil Pesto
#  - Marinara Pasta Sauce
#  - Spaghetti
# Department 'frozen':
#  - Blueberries
#  - Organic Broccoli Florets
#  - Organic Whole Strawberries
#  - Pineapple Chunks
#  - Frozen Organic Wild Blueberries
# Department 'household':
#  - 100% Recycled Paper Towels
#  - Sustainably Soft Bath Tissue
#  - Aluminum Foil
#  - White Giant Paper Towel Rolls
#  - Select-A-Size White Paper Towels
# Department 'international':
#  - Organic Sea Salt Roasted Seaweed Snacks
#  - Taco Seasoning
#  - Sriracha Chili Sauce
#  - New Mexico Taco Skillet Sauce For Chicken
#  - Coconut Milk
# Department 'meat seafood':
#  - Boneless Skinless Chicken Breasts
#  - Uncured Hickory Smoked Sunday Bacon
#  - Ground Turkey Breast
#  - Boneless Skinless Chicken Breast
#  - Natural Chicken & Sage Breakfast Sausage
# Department 'missing':
#  - Organic Riced Cauliflower
#  - Natural Lemon Flavored Sparkling Water
#  - Peanut Butter Ice Cream Cup
#  - Organic Uncured Beef Hot Dog
#  - Organic Celery Bunch
# Department 'other':
#  - Roasted Almond Butter
#  - Light CocoWhip! Coconut Whipped Topping
#  - Coffee Mate French Vanilla Creamer Packets
#  - Kiwifruit
#  - Roasted Unsalted Almonds
# Department 'pantry':
#  - Extra Virgin Olive Oil
#  - Creamy Peanut Butter
#  - Creamy Almond Butter
#  - Organic Medium Salsa
#  - Organic Extra Virgin Olive Oil
# Department 'personal care':
#  - Lavender Hand Soap
#  - Cotton Swabs
#  - Fluoride-Free Antiplaque & Whitening Peppermint Toothpaste
#  - Lemon Verbena Hand Soap
#  - Epsom Salt
# Department 'pets':
#  - Grain Free Chicken Formula Cat Food
#  - Double Duty Advanced Odor Control Clumping Cat Litter
#  - 24/7 Performance Light Weight Cat Litter
#  - Grilled Ocean Whitefish & Tuna Feast in Gravy Cat Food
#  - Adult Indoor Advantage Cat Food
# Department 'produce':
#  - Banana
#  - Bag of Organic Bananas
#  - Organic Strawberries
#  - Organic Baby Spinach
#  - Large Lemon
# Department 'snacks':
#  - Lightly Salted Baked Snap Pea Crisps
#  - Organic Tortilla Chips
#  - Trail Mix
#  - Chocolate Chip Cookies
#  - Sea Salt Pita Chips

# %% [markdown]
# ## I) Quais são os 2 corredores (`aisles`) que são visitados juntos no mesmo pedido mais vezes em uma sexta-feira?

# %%
""" Entre com o Código aqui """
friday_orders = dataset[dataset.order_dow == "friday"]
aisles_visit_count = pd.crosstab(friday_orders.order_id, friday_orders.aisle)
aisles_visit_count.head()
# Out:
# aisle     air fresheners candles  asian foods  baby accessories  \
# order_id
# 36                             0            0                 0
# 38                             0            0                 0
# 96                             0            0                 0
# 393                            0            0                 0
# 473                            0            0                 0
#
# aisle     baby bath body care  baby food formula  bakery desserts  \
# order_id
# 36                          0                  0                0
# 38                          0                  0                0
# 96                          0                  0                0
# 393                         0                  0                0
# 473                         0                  0                0
#
# aisle     baking ingredients  baking supplies decor  beauty  beers coolers  \
# order_id
# 36                         0                      0       0              0
# 38                         0                      0       0              0
# 96                         0                      0       0              0
# 393                        0                      0       0              0
# 473                        0                      0       0              0
#
# aisle      ...    spreads  tea  tofu meat alternatives  tortillas flat bread  \
# order_id   ...
# 36         ...          0    0                       0                     0
# 38         ...          0    0                       0                     0
# 96         ...          0    0                       0                     0
# 393        ...          0    0                       0                     0
# 473        ...          0    0                       0                     0
#
# aisle     trail mix snack mix  trash bags liners  vitamins supplements  \
# order_id
# 36                          0                  0                     0
# 38                          0                  0                     0
# 96                          0                  0                     0
# 393                         0                  0                     0
# 473                         0                  0                     0
#
# aisle     water seltzer sparkling water  white wines  yogurt
# order_id
# 36                                    1            0       0
# 38                                    0            0       0
# 96                                    0            0       0
# 393                                   0            0       0
# 473                                   0            0       0
#
# [5 rows x 134 columns]

# %%
aisles_visit_count = aisles_visit_count.applymap(lambda x: 1 if x > 0 else 0)

# %%
co_occurrent_aisles = aisles_visit_count.T

# %%
co_occurrent_aisles = co_occurrent_aisles.dot(aisles_visit_count)
co_occurrent_aisles.head()
# Out:
# aisle                   air fresheners candles  asian foods  baby accessories  \
# aisle
# air fresheners candles                     129            9                 0
# asian foods                                  9          805                 2
# baby accessories                             0            2                39
# baby bath body care                          1            3                 2
# baby food formula                            5           34                 7
#
# aisle                   baby bath body care  baby food formula  \
# aisle
# air fresheners candles                    1                  5
# asian foods                               3                 34
# baby accessories                          2                  7
# baby bath body care                      40                  7
# baby food formula                         7                615
#
# aisle                   bakery desserts  baking ingredients  \
# aisle
# air fresheners candles                2                   8
# asian foods                           8                 103
# baby accessories                      0                   5
# baby bath body care                   1                   2
# baby food formula                     8                  67
#
# aisle                   baking supplies decor  beauty  beers coolers   ...    \
# aisle                                                                  ...
# air fresheners candles                      0       0              0   ...
# asian foods                                12       2              6   ...
# baby accessories                            1       0              0   ...
# baby bath body care                         0       0              1   ...
# baby food formula                           2       2              2   ...
#
# aisle                   spreads  tea  tofu meat alternatives  \
# aisle
# air fresheners candles        9   11                       2
# asian foods                  92   51                      78
# baby accessories              5    2                       2
# baby bath body care           5    3                       0
# baby food formula            83   33                      33
#
# aisle                   tortillas flat bread  trail mix snack mix  \
# aisle
# air fresheners candles                     8                    0
# asian foods                               80                    8
# baby accessories                           4                    1
# baby bath body care                        4                    1
# baby food formula                         45                    9
#
# aisle                   trash bags liners  vitamins supplements  \
# aisle
# air fresheners candles                  7                     2
# asian foods                             7                    20
# baby accessories                        1                     6
# baby bath body care                     2                     4
# baby food formula                       8                    11
#
# aisle                   water seltzer sparkling water  white wines  yogurt
# aisle
# air fresheners candles                             41            2      28
# asian foods                                       181            6     244
# baby accessories                                   13            0      19
# baby bath body care                                11            0      17
# baby food formula                                 156            4     297
#
# [5 rows x 134 columns]

# %%
co_occurrent_aisles -= np.triu(co_occurrent_aisles)
co_occurrent_aisles.head()
# Out:
# aisle                   air fresheners candles  asian foods  baby accessories  \
# aisle
# air fresheners candles                       0            0                 0
# asian foods                                  9            0                 0
# baby accessories                             0            2                 0
# baby bath body care                          1            3                 2
# baby food formula                            5           34                 7
#
# aisle                   baby bath body care  baby food formula  \
# aisle
# air fresheners candles                    0                  0
# asian foods                               0                  0
# baby accessories                          0                  0
# baby bath body care                       0                  0
# baby food formula                         7                  0
#
# aisle                   bakery desserts  baking ingredients  \
# aisle
# air fresheners candles                0                   0
# asian foods                           0                   0
# baby accessories                      0                   0
# baby bath body care                   0                   0
# baby food formula                     0                   0
#
# aisle                   baking supplies decor  beauty  beers coolers   ...    \
# aisle                                                                  ...
# air fresheners candles                      0       0              0   ...
# asian foods                                 0       0              0   ...
# baby accessories                            0       0              0   ...
# baby bath body care                         0       0              0   ...
# baby food formula                           0       0              0   ...
#
# aisle                   spreads  tea  tofu meat alternatives  \
# aisle
# air fresheners candles        0    0                       0
# asian foods                   0    0                       0
# baby accessories              0    0                       0
# baby bath body care           0    0                       0
# baby food formula             0    0                       0
#
# aisle                   tortillas flat bread  trail mix snack mix  \
# aisle
# air fresheners candles                     0                    0
# asian foods                                0                    0
# baby accessories                           0                    0
# baby bath body care                        0                    0
# baby food formula                          0                    0
#
# aisle                   trash bags liners  vitamins supplements  \
# aisle
# air fresheners candles                  0                     0
# asian foods                             0                     0
# baby accessories                        0                     0
# baby bath body care                     0                     0
# baby food formula                       0                     0
#
# aisle                   water seltzer sparkling water  white wines  yogurt
# aisle
# air fresheners candles                              0            0       0
# asian foods                                         0            0       0
# baby accessories                                    0            0       0
# baby bath body care                                 0            0       0
# baby food formula                                   0            0       0
#
# [5 rows x 134 columns]

# %%
co_occurrent_aisles.stack().sort_values(ascending=False).head(1)
# Out:
# aisle             aisle
# fresh vegetables  fresh fruits    5809
# dtype: int64

# %% [markdown]
# ## J) Quais as duplas de produtos que mais saem juntas no pedido (`order_id`) de um usuário em uma sexta-feira?

# %%
""" Entre com o Código aqui """
# %time
friday_orders = dataset[dataset.order_dow == "friday"]
products_count = (pd.crosstab(friday_orders.order_id, friday_orders.product_name) > 0).astype(float)
co_occurrent_products = products_count.T.dot(products_count)
co_occurrent_products -= np.triu(co_occurrent_products)
# Out:
# Wall time: 2 ms

# %%
co_occurrent_products.stack().sort_values(ascending=False).head(1)
